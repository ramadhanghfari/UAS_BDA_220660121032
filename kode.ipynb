# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# Data transaksi
data = {
    'Canvas Art': [1, 0, 1, 0, 1],
    'Keychain': [1, 0, 0, 1, 1],
    'Mug': [1, 1, 1, 0, 1],
    'Stiker Member Hololive ID': [1, 0, 1, 1, 1],
    'Akrilik Diorama Stand': [0, 1, 1, 1, 1]
}

df = pd.DataFrame(data)

# Menghasilkan frequent itemsets
frequent_itemsets = apriori(df, min_support=0.4, use_colnames=True)

# Menghasilkan aturan asosiasi
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Menampilkan hasil
print(frequent_itemsets)
print(rules)
# Out:
#     support                                           itemsets
# 0       0.6                                       (Canvas Art)
# 1       0.6                                         (Keychain)
# 2       0.8                                              (Mug)
# 3       0.8                        (Stiker Member Hololive ID)
# 4       0.8                            (Akrilik Diorama Stand)
# 5       0.4                             (Canvas Art, Keychain)
# 6       0.6                                  (Canvas Art, Mug)
# 7       0.6            (Canvas Art, Stiker Member Hololive ID)
# 8       0.4                (Canvas Art, Akrilik Diorama Stand)
# 9       0.4                                    (Keychain, Mug)
# 10      0.6              (Keychain, Stiker Member Hololive ID)
# 11      0.4                  (Keychain, Akrilik Diorama Stand)
# 12      0.6                   (Mug, Stiker Member Hololive ID)
# 13      0.6                       (Akrilik Diorama Stand, Mug)
# 14      0.6  (Akrilik Diorama Stand, Stiker Member Hololive...
# 15      0.4                        (Canvas Art, Keychain, Mug)
# 16      0.4  (Canvas Art, Keychain, Stiker Member Hololive ID)
# 17      0.6       (Canvas Art, Mug, Stiker Member Hololive ID)
# 18      0.4           (Canvas Art, Akrilik Diorama Stand, Mug)
# 19      0.4  (Canvas Art, Akrilik Diorama Stand, Stiker Mem...
# 20      0.4         (Keychain, Mug, Stiker Member Hololive ID)
# 21      0.4  (Keychain, Akrilik Diorama Stand, Stiker Membe...
# 22      0.4  (Akrilik Diorama Stand, Mug, Stiker Member Hol...
# 23      0.4  (Canvas Art, Keychain, Mug, Stiker Member Holo...
# 24      0.4  (Canvas Art, Akrilik Diorama Stand, Mug, Stike...
#                                           antecedents  \
# 0                                        (Canvas Art)
# 1                                          (Keychain)
# 2                                        (Canvas Art)
# 3                                               (Mug)
# 4                                        (Canvas Art)
# ..                                                ...
# 63  (Akrilik Diorama Stand, Stiker Member Hololive...
# 64                   (Mug, Stiker Member Hololive ID)
# 65                                       (Canvas Art)
# 66                                              (Mug)
# 67                        (Stiker Member Hololive ID)
#
#                                           consequents  antecedent support  \
# 0                                          (Keychain)                 0.6
# 1                                        (Canvas Art)                 0.6
# 2                                               (Mug)                 0.6
# 3                                        (Canvas Art)                 0.8
# 4                         (Stiker Member Hololive ID)                 0.6
# ..                                                ...                 ...
# 63                                  (Canvas Art, Mug)                 0.6
# 64                (Canvas Art, Akrilik Diorama Stand)                 0.6
# 65  (Akrilik Diorama Stand, Mug, Stiker Member Hol...                 0.6
# 66  (Canvas Art, Akrilik Diorama Stand, Stiker Mem...                 0.8
# 67           (Canvas Art, Akrilik Diorama Stand, Mug)                 0.8
#
#     consequent support  support  confidence      lift  leverage  conviction  \
# 0                  0.6      0.4    0.666667  1.111111      0.04         1.2
# 1                  0.6      0.4    0.666667  1.111111      0.04         1.2
# 2                  0.8      0.6    1.000000  1.250000      0.12         inf
# 3                  0.6      0.6    0.750000  1.250000      0.12         1.6
# 4                  0.8      0.6    1.000000  1.250000      0.12         inf
# ..                 ...      ...         ...       ...       ...         ...
# 63                 0.6      0.4    0.666667  1.111111      0.04         1.2
# 64                 0.4      0.4    0.666667  1.666667      0.16         1.8
# 65                 0.4      0.4    0.666667  1.666667      0.16         1.8
# 66                 0.4      0.4    0.500000  1.250000      0.08         1.2
# 67                 0.4      0.4    0.500000  1.250000      0.08         1.2
#
#     zhangs_metric
# 0            0.25
# 1            0.25
# 2            0.50
# 3            1.00
# 4            0.50
# ..            ...
# 63           0.25
# 64           1.00
# 65           1.00
# 66           1.00
# 67           1.00
#
# [68 rows x 10 columns]
# C:\Users\Lenovo\anaconda3\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
